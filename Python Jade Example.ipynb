# %% [markdown]
# Load .mat file from MATLAB

# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
from pynoci import jadeR
from pynoci import noci
# %matplotlib inline

# %% [markdown]
# loadmat returns a Dict with the content of the mat file

# %%
mat_contents = sio.loadmat('./pynoci/art.mat')
mat_contents2 = sio.loadmat('./pynoci/Set3.mat')

# %% [markdown]
# Extract one variable from the file into a numpy.array

# %%
art = mat_contents['art']
S = mat_contents2['S']

# %%
print(S.shape)
plot1 = plt.plot(S.T)
# Out:
# (4, 50000)

# %%
m = 40
[n,t] = S.shape
A = np.random.rand(m,n)
X = np.dot(A,S)

# %%
B = jadeR.jadeR(X=X,m=5,verbose=True)
# Out:
# jade -> Looking for 5 sources
# jade -> Removing the mean value
# jade -> Whitening the data
# jade -> Estimating cumulant matrices
# jade -> Contrast optimization by joint diagonalization
# jade -> Sweep #  0 completed in 10 rotations
# jade -> Sweep #  1 completed in 6 rotations
# jade -> Sweep #  2 completed in 6 rotations
# jade -> Sweep #  3 completed in 3 rotations
# jade -> Sweep #  4 completed in 3 rotations
# jade -> Sweep #  5 completed in 0 rotations
# jade -> Total of 28 Givens rotations
# jade -> Sorting the components
# jade -> Fixing the signs
# /media/mercaderd/DATA/Google Drive/Master ISC/TFM/pynoci/pynoci/jadeR.py:224: ComplexWarning: Casting complex values to real discards the imaginary part
#   CM[:,Range] = Qij
# /media/mercaderd/DATA/Google Drive/Master ISC/TFM/pynoci/pynoci/jadeR.py:230: ComplexWarning: Casting complex values to real discards the imaginary part
#   CM[:,Range]	= Qij
# ...

# %%
noci.dwcriterion(X,maxICs=10,verbose=1)
# Out:
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:224: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:338: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:230: ComplexWarning: Casting complex values to real discards the imaginary part
# array([[ 0.64196703,  0.22209774,  0.30162746,  0.29120067,  0.59461813,
#          1.1128127 ,  0.19494587,  0.32891605,  1.10119715,  0.94216508,
#          0.7144514 ,  1.05699341,  0.50849056,  0.74927007,  0.40193297,
#          0.86696449,  0.45902852,  0.34567506,  0.72629769,  0.49495218,
#          0.51527423,  0.66302353,  0.36825424,  0.52855369,  0.69502434,
#          0.49400838,  0.65325698,  0.89810206,  0.36946276,  0.20307112,
# ...

# %%
noci.ICA_by_two_blocks(X,maxICs=14)
# Out:
# 14
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:224: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:338: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:230: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3003: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/numpy/lib/function_base.py:3004: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# [array([ 0.99728798]),
#  array([ 0.97702292,  0.97345107]),
#  array([ 0.99928875,  0.99902222,  0.99784917]),
# ...

# %%
noci.lcc(X)
# Out:
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:224: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:230: ComplexWarning: Casting complex values to real discards the imaginary part
# /home/mercaderd/anaconda3/lib/python3.5/site-packages/ica_tools-0.0.1-py3.5.egg/noci/jadeR.py:338: ComplexWarning: Casting complex values to real discards the imaginary part
# 4
